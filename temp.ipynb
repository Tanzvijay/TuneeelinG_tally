# %%
import psycopg2

conn = psycopg2.connect(
    host="db-postgresdod-nyc3-08443-do-user-18717265-0.e.db.ondigitalocean.com",
    port="25060",
    database="Sun_it_tally",
    user="developer_dod",
    password="AVNS_qsSPxFK22rFNaxqNZmX"
)

cur = conn.cursor()

cur.execute("SELECT version();")
print(cur.fetchone())

cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[3], line 3
#       1 import psycopg2
# ----> 3 conn = psycopg2.connect(
#       4     host="db-postgresdod-nyc3-08443-do-user-18717265-0.e.db.ondigitalocean.com",
#       5     port="25060",
#       6     database="Sun_it_tally",
#       7     user="developer_dod",
#       8     password="AVNS_ksIVKVtXa2Oj6d_EcG7"
#       9 )
#      11 cur = conn.cursor()
#      13 cur.execute("SELECT version();")
#
# File c:\Users\vijay\AppData\Local\Programs\Python\Python311\Lib\site-packages\psycopg2\__init__.py:135, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     132     kwasync['async_'] = kwargs.pop('async_')
#     134 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 135 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     136 if cursor_factory is not None:
# ...
